# %%
import sys
sys.path.append('..')  
import scripts.script1

out = scripts.script1.blah()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 sys.path.append('..')
#       2 import scripts.script1
#       4 out = scripts.script1.blah()
#
# NameError: name 'sys' is not defined

# %%
import scripts.script1
sys.path.append('..')  

out = scripts.script1.linear_regression_widget()
# Out:
# Output()
# GridspecLayout(children=(Label(value='Hældningskoefficient: ', layout=Layout(grid_area='widget001')), Label(va…
